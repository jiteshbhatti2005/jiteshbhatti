# %% [markdown]
# ######

# %%
########################################################################################################
#Name : - Jitesh Bhatti 
#Enrollment :- 216270307057
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 6 : Write a Pandas program to implement following operation

#Practical - 6.1 to convert a NumPy array to a Pandas series

import pandas as pd
import numpy as np


n_arr = np.array([1, 2, 3, 4, 5])
p_series = pd.Series(n_arr)

print(p_series)

# %%
########################################################################################################
#Name : - Jitesh Bhatti 
#Enrollment :- 216270307057
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 6 : Write a Pandas program to implement following operation

#Practical - 6.2 to convert the first column of a DataFrame as a Series

import pandas as pd

data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

series = df['A']
print(series)

# %%
########################################################################################################
#Name : - Jitesh Bhatti 
#Enrollment :- 216270307057
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 6 : Write a Pandas program to implement following operation

#Practical - 6.3 to create the mean and standard deviation of the data of a given Series

import pandas as pd

data = [1, 2, 3, 4, 5]
series = pd.Series(data)

mean = series.mean()
deviation = series.std()

print("Mean:", mean)
print("Standard Deviation:", deviation)

# %%
########################################################################################################
#Name : - Jitesh Bhatti 
#Enrollment :- 216270307057
#Subject :- IML
#Sem :- 5
########################################################################################################

#Practical - 6 : Write a Pandas program to implement following operation

#Practical - 6.4 to sort a given Series

import pandas as pd

data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
series = pd.Series(data)
sorted_s = series.sort_values()

print(sorted_s)
